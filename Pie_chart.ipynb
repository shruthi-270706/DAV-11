# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthi-uligonda/DAV-11/blob/main/Pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
sizes = [20,30,25,35]
labels = ['Apples','Bananas','Cherries', 'Dates']
colors = ['gold', 'lightblue','lightgreen','pink']
explode = [0,0.1,0,0]
plt.pie(sizes,labels=labels,colors=colors,explode=explode,autopct='%1.1f%%',shadow=True)
plt.title("Pie Chart Example")
plt.show()
