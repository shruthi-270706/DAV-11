# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthi-uligonda/DAV-11/blob/main/Assigment_1_Thursday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data for Excel
data = {
    'RollNo': [101, 102, 103, None, 105],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', None],
    'Math': [45, 32, None, 50, 40],
    'Science': [50, 28, 35, None, 45],
    'English': [40, None, 30, 48, 42]
}

df = pd.DataFrame(data)
df = pd.read_excel('student_marks.xlsx')
df.head()
# Out:
#    RollNo     Name  Math  Science  English
# 0   101.0    Alice  45.0     50.0     40.0
# 1   102.0      Bob  32.0     28.0      NaN
# 2   103.0  Charlie   NaN     35.0     30.0
# 3     NaN    David  50.0      NaN     48.0
# 4   105.0      NaN  40.0     45.0     42.0
